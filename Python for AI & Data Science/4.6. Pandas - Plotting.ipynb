# %%
## Present simple plot

# %%
import pandas as pd

# %%
df = pd.read_csv('jumlah_usaha_pengaju..csv')
df.plot()
# Out:
# <AxesSubplot:>

# %%
df.shape
# Out:
# (27, 8)

# %%
# Present Scatter Plot

# %%
df.plot(kind='scatter', x='nama_kabupaten_kota', y='jumlah_usaha')
# Out:
# <AxesSubplot:xlabel='nama_kabupaten_kota', ylabel='jumlah_usaha'>

# %%
## Present Histogram

# %%
df['jumlah_usaha'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>
